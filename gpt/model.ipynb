# %%
from promptify import OpenAI
from promptify import Prompter
import pprint


def get_prompt():
    doc_file = open("/home/jovyan/work/data/text.txt")
    doc_file = doc_file.read()
    print(doc_file)
    sentence = "The patient is a 93-year-old female with a medical" \
               " history of chronic right hip pain, osteoporosis, hypertension, d" \
               "epression, and chronic atrial fibrillation admitted for evaluation " \
               "and management of severe nausea and vomiting and urinary tract infection"

    api_key = "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"

    model = OpenAI(api_key)  # or `HubModel()` for Huggingface-based inference
    nlp_prompter = Prompter(model)

    return nlp_prompter.fit('ner.jinja',
                              domain='financial',
                              text_input=sentence,
                              labels=None)

# %%
result = get_prompt()
# Out:
# Sarah Johnson is a resident of Amsterdam, Netherlands with BSN number 123456789. She has provided her email address sarah.johnson@example.com and phone number +31 6 12345678 to a healthcare provider for the purpose of booking an appointment. In addition, she has disclosed her health information, specifically that she has a pre-existing condition of asthma, to the provider. This information will be used to assess her medical needs and provide appropriate care.
#
# The healthcare provider is committed to complying with GDPR regulations and has obtained explicit consent from Sarah Johnson for the collection and processing of her personal data. They have also implemented appropriate measures to ensure the security and protection of her data, in accordance with GDPR guidelines.
#
# ...

# %%
print(result['text'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(result['text'])
#
# NameError: name 'result' is not defined
