# %%
import spacy
from spacy import displacy
import pandas as pd
from pprint import pprint
from spacy.matcher import Matcher
import os
os.chdir("/home/jovyan/work/spacy")
nlp = spacy.load("en_core_web_sm")
matcher = Matcher(nlp.vocab)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import spacy
#       2 from spacy import displacy
#       3 import pandas as pd
#
# File ~/.local/lib/python3.10/site-packages/spacy/__init__.py:6
#       3 import sys
#       5 # set library-specific custom warning handling before doing anything else
# ----> 6 from .errors import setup_default_warnings
#       8 setup_default_warnings()  # noqa: E402
#      10 # These are imported as part of the API
#
# File ~/.local/lib/python3.10/site-packages/spacy/errors.py:2
#       1 import warnings
# ----> 2 from .compat import Literal
#       5 class ErrorsWithCodes(type):
#       6     def __getattribute__(self, code):
#
# File ~/.local/lib/python3.10/site-packages/spacy/compat.py:3
#       1 """Helpers for Python and platform compatibility."""
#       2 import sys
# ----> 3 from thinc.util import copy_array
#       5 try:
#       6     import cPickle as pickle
#
# File ~/.local/lib/python3.10/site-packages/thinc/__init__.py:5
#       2 import numpy
#       4 from .about import __version__
# ----> 5 from .config import registry
#       8 # fmt: off
#       9 __all__ = [
#      10     "registry",
#      11     "__version__",
#      12 ]
#
# File ~/.local/lib/python3.10/site-packages/thinc/config.py:4
#       2 import confection
#       3 from confection import Config, ConfigValidationError, Promise, VARIABLE_RE
# ----> 4 from .types import Decorator
#       7 class registry(confection.registry):
#       8     # fmt: off
#       9     optimizers: Decorator = catalogue.create("thinc", "optimizers", entry_points=True)
#
# File ~/.local/lib/python3.10/site-packages/thinc/types.py:8
#       6 import numpy
#       7 import sys
# ----> 8 from .compat import has_cupy, cupy
#      10 if has_cupy:
#      11     get_array_module = cupy.get_array_module
#
# File ~/.local/lib/python3.10/site-packages/thinc/compat.py:54
#      51     torch_version = Version("0.0.0")
#      53 try:  # pragma: no cover
# ---> 54     import tensorflow.experimental.dlpack
#      55     import tensorflow
#      57     has_tensorflow = True
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/__init__.py:476
#     474 if hasattr(_current_module, "keras"):
#     475   try:
# --> 476     _keras._load()
#     477   except ImportError:
#     478     pass
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/lazy_loader.py:41, in LazyLoader._load(self)
#      39 """Load the module and insert it into the parent's globals."""
#      40 # Import the target module and insert it into the parent's namespace
# ---> 41 module = importlib.import_module(self.__name__)
#      42 self._parent_module_globals[self._local_name] = module
#      44 # Emit a warning if one was specified
#
# File /usr/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File /usr/local/lib/python3.10/dist-packages/keras/__init__.py:25
#      22 from keras import distribute
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from keras import models
#      27 from keras.engine.input_layer import Input
#      28 from keras.engine.sequential import Sequential
#
# File /usr/local/lib/python3.10/dist-packages/keras/models.py:20
#      18 import tensorflow.compat.v2 as tf
#      19 from keras import backend
# ---> 20 from keras import metrics as metrics_module
#      21 from keras import optimizer_v1
#      22 from keras.engine import functional
#
# File /usr/local/lib/python3.10/dist-packages/keras/metrics.py:26
#      23 import warnings
#      25 import numpy as np
# ---> 26 from keras import activations
#      27 from keras import backend
#      28 from keras.engine import base_layer
#
# File /usr/local/lib/python3.10/dist-packages/keras/activations.py:20
#      17 import tensorflow.compat.v2 as tf
#      19 from keras import backend
# ---> 20 from keras.layers import advanced_activations
#      21 from keras.utils.generic_utils import deserialize_keras_object
#      22 from keras.utils.generic_utils import serialize_keras_object
#
# File /usr/local/lib/python3.10/dist-packages/keras/layers/__init__.py:23
#      20 from tensorflow.python import tf2
#      22 # Generic layers.
# ---> 23 from keras.engine.input_layer import Input
#      24 from keras.engine.input_layer import InputLayer
#      25 from keras.engine.input_spec import InputSpec
#
# File /usr/local/lib/python3.10/dist-packages/keras/engine/input_layer.py:21
#      19 from keras import backend
#      20 from keras.distribute import distributed_training_utils
# ---> 21 from keras.engine import base_layer
#      22 from keras.engine import keras_tensor
#      23 from keras.engine import node as node_module
#
# File /usr/local/lib/python3.10/dist-packages/keras/engine/base_layer.py:45
#      43 from keras.mixed_precision import loss_scale_optimizer
#      44 from keras.mixed_precision import policy
# ---> 45 from keras.saving.saved_model import layer_serialization
#      46 from keras.utils import generic_utils
#      47 from keras.utils import layer_utils
#
# File /usr/local/lib/python3.10/dist-packages/keras/saving/saved_model/layer_serialization.py:20
#      18 from keras.saving.saved_model import base_serialization
#      19 from keras.saving.saved_model import constants
# ---> 20 from keras.saving.saved_model import save_impl
#      21 from keras.saving.saved_model import serialized_attributes
#      22 from keras.utils import generic_utils
#
# File /usr/local/lib/python3.10/dist-packages/keras/saving/saved_model/save_impl.py:31
#      29 from keras.saving import saving_utils
#      30 from keras.saving.saved_model import constants
# ---> 31 from keras.saving.saved_model import load as keras_load
#      32 from keras.saving.saved_model import serialized_attributes
#      33 from keras.saving.saved_model import utils
#
# File /usr/local/lib/python3.10/dist-packages/keras/saving/saved_model/load.py:25
#      23 from keras.engine import input_spec
#      24 from keras.optimizer_v2 import optimizer_v2
# ---> 25 from keras.protobuf import saved_metadata_pb2
#      26 from keras.protobuf import versions_pb2
#      27 from keras.saving import saving_utils
#
# File /usr/local/lib/python3.10/dist-packages/keras/protobuf/saved_metadata_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from keras.protobuf import versions_pb2 as keras_dot_protobuf_dot_versions__pb2
#      19 DESCRIPTOR = _descriptor.FileDescriptor(
#      20   name='keras/protobuf/saved_metadata.proto',
#      21   package='third_party.py.keras.protobuf',
#    (...)
#      25   ,
#      26   dependencies=[keras_dot_protobuf_dot_versions__pb2.DESCRIPTOR,])
#      31 _SAVEDMETADATA = _descriptor.Descriptor(
#      32   name='SavedMetadata',
#      33   full_name='third_party.py.keras.protobuf.SavedMetadata',
#    (...)
#      58   serialized_end=175,
#      59 )
#
# File /usr/local/lib/python3.10/dist-packages/keras/protobuf/versions_pb2.py:36
#      13 _sym_db = _symbol_database.Default()
#      18 DESCRIPTOR = _descriptor.FileDescriptor(
#      19   name='keras/protobuf/versions.proto',
#      20   package='third_party.py.keras.protobuf',
#    (...)
#      23   serialized_pb=_b('\n\x1dkeras/protobuf/versions.proto\x12\x1dthird_party.py.keras.protobuf\"K\n\nVersionDef\x12\x10\n\x08producer\x18\x01 \x01(\x05\x12\x14\n\x0cmin_consumer\x18\x02 \x01(\x05\x12\x15\n\rbad_consumers\x18\x03 \x03(\x05\x62\x06proto3')
#      24 )
#      29 _VERSIONDEF = _descriptor.Descriptor(
#      30   name='VersionDef',
#      31   full_name='third_party.py.keras.protobuf.VersionDef',
#      32   filename=None,
#      33   file=DESCRIPTOR,
#      34   containing_type=None,
#      35   fields=[
# ---> 36     _descriptor.FieldDescriptor(
#      37       name='producer', full_name='third_party.py.keras.protobuf.VersionDef.producer', index=0,
#      38       number=1, type=5, cpp_type=1, label=1,
#      39       has_default_value=False, default_value=0,
#      40       message_type=None, enum_type=None, containing_type=None,
#      41       is_extension=False, extension_scope=None,
#      42       serialized_options=None, file=DESCRIPTOR),
#      43     _descriptor.FieldDescriptor(
#      44       name='min_consumer', full_name='third_party.py.keras.protobuf.VersionDef.min_consumer', index=1,
#      45       number=2, type=5, cpp_type=1, label=1,
#      46       has_default_value=False, default_value=0,
#      47       message_type=None, enum_type=None, containing_type=None,
#      48       is_extension=False, extension_scope=None,
#      49       serialized_options=None, file=DESCRIPTOR),
#      50     _descriptor.FieldDescriptor(
#      51       name='bad_consumers', full_name='third_party.py.keras.protobuf.VersionDef.bad_consumers', index=2,
#      52       number=3, type=5, cpp_type=1, label=3,
#      53       has_default_value=False, default_value=[],
#      54       message_type=None, enum_type=None, containing_type=None,
#      55       is_extension=False, extension_scope=None,
#      56       serialized_options=None, file=DESCRIPTOR),
#      57   ],
#      58   extensions=[
#      59   ],
#      60   nested_types=[],
#      61   enum_types=[
#      62   ],
#      63   serialized_options=None,
#      64   is_extendable=False,
#      65   syntax='proto3',
#      66   extension_ranges=[],
#      67   oneofs=[
#      68   ],
#      69   serialized_start=64,
#      70   serialized_end=139,
#      71 )
#      73 DESCRIPTOR.message_types_by_name['VersionDef'] = _VERSIONDEF
#      74 _sym_db.RegisterFileDescriptor(DESCRIPTOR)
#
# File /usr/local/lib/python3.10/dist-packages/google/protobuf/descriptor.py:561, in FieldDescriptor.__new__(cls, name, full_name, index, number, type, cpp_type, label, default_value, message_type, enum_type, containing_type, is_extension, extension_scope, options, serialized_options, has_default_value, containing_oneof, json_name, file, create_key)
#     555 def __new__(cls, name, full_name, index, number, type, cpp_type, label,
#     556             default_value, message_type, enum_type, containing_type,
#     557             is_extension, extension_scope, options=None,
#     558             serialized_options=None,
#     559             has_default_value=True, containing_oneof=None, json_name=None,
#     560             file=None, create_key=None):  # pylint: disable=redefined-builtin
# --> 561   _message.Message._CheckCalledFromGeneratedFile()
#     562   if is_extension:
#     563     return _message.default_pool.FindExtensionByName(full_name)
#
# TypeError: Descriptors cannot not be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates

# %%
doc_file = open("/home/jovyan/work/data/text.txt")
doc_content = doc_file.read()
doc_nlp = nlp(doc_content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 doc_file = open("/home/jovyan/work/data/text.txt")
#       2 doc_content = doc_file.read()
#       3 doc_nlp = nlp(doc_content)
#
# File /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jovyan/work/data/text.txt'

# %%
# removeing the stop words (most commone words that used in english and dosn't mean anything)
# check the list with nlp.

# no_stop = nlp()

# for t in doc_nlp:
#        if nlp.vocab[t.text].is_stop :

# %%
for t in doc_nlp:
        if t.pos_ == "PROPN" or t.pos_ == "NN":
                    print(f'{t.text:{12}} {t.pos_:{6}}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 for t in doc_nlp:
#       2         if t.pos_ == "PROPN" or t.pos_ == "NN":
#       3                     print(f'{t.text:{12}} {t.pos_:{6}}')
#
# NameError: name 'doc_nlp' is not defined

# %%
for ent in doc_nlp.ents:
  if ent.label_ == "PERSON":
    print(f'{ent.text:{25}} {ent.label_:{6}} {ent.start_char:{6}} {ent.end_char:{6}}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 for ent in doc_nlp.ents:
#       2   if ent.label_ == "PERSON":
#       3     print(f'{ent.text:{25}} {ent.label_:{6}} {ent.start_char:{6}} {ent.end_char:{6}}')
#
# NameError: name 'doc_nlp' is not defined

# %%
pattern1 = [{"ENT_TYPE": "PERSON"}]
pattern2 = [{"POS": "PROPN"},{"POS": "PROPN"}]
pattern3 = [{"POS": "NN"},{"POS": "NN"}]
pattern4 = [{"POS": "PROPN"},{"POS": "NN"}]
pattern5 = [{"POS": "NN"},{"POS": "PROPN"}]
pattern6 = [{"POS": "NN"}]
pattern7 = [{"POS": "PROPN"}]
pattern8 = [{"POS": "PROPN"},{"POS": "PROPN"},{"POS": "PROPN"}]
pattern9 = [{"POS": "NN"},{"POS": "NN"},{"POS": "NN"}]
pattern10 = [{"POS": "PROPN"},{"POS": "PROPN"},{"POS": "NN"}]
pattern11 = [{"POS": "PROPN"},{"POS": "NN"},{"POS": "NN"}]

matcher.add("Names",[pattern1,pattern2,pattern3,pattern4,pattern5,pattern6,pattern7,pattern8,pattern9,pattern10,pattern11])
matches = matcher(doc_nlp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 14
#      11 pattern11 = [{"POS": "PROPN"},{"POS": "NN"},{"POS": "NN"}]
#      13 matcher.add("Names",[pattern1,pattern2,pattern3,pattern4,pattern5,pattern6,pattern7,pattern8,pattern9,pattern10,pattern11])
# ---> 14 matches = matcher(doc_nlp)
#
# NameError: name 'doc_nlp' is not defined

# %%
for match_id, start, end in matches:
    string_id = nlp.vocab.strings[match_id]  # Get string representation
    span = doc_nlp[start:end]  # The matched span
    print(match_id, string_id, start, end, span.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 for match_id, start, end in matches:
#       2     string_id = nlp.vocab.strings[match_id]  # Get string representation
#       3     span = doc_nlp[start:end]  # The matched span
#
# NameError: name 'matches' is not defined
